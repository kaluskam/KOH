# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import Image

# %%
def load_history(path):
    history = pd.read_csv(path, index_col=0)
    return history


def mean_scores(histories):
    n = len(histories)
    scores = np.zeros(len(histories[0]))
    for i in range(n):
        scores += histories[i]['adjusted rand score']
    return pd.DataFrame(scores / 5)

# %% [markdown]
# # Sprawozdanie KOH1
# Maria Kędzierska 305704

# %% [markdown]
# # Hexagon

# %% [markdown]
# ## Architektura (2, 3) + funkcja gaussa
# Najlepiej sprawdził się współczynnik sąsiedztwa 0.7. Jednak wszystkie wyniki są porównywalne.

# %% [markdown]
# ### Współczynnik sąsiedztwa = 1

# %%
path_name = '..\\evaluation\\(2, 3)_1_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/(2, 3)_1_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.542722
# 0    5.0                  0.842334
# 0   10.0                  0.880169
# 0   15.0                  0.910948
# 0   20.0                  0.928938
# Przykładowa wizualizacja

# %% [markdown]
# ### Współczynnik sąsiedztwa = 0.7

# %%
path_name = '..\\evaluation\\(2, 3)_0.7_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/(2, 3)_0.7_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.589931
# 0    5.0                  0.829596
# 0   10.0                  0.904357
# 0   15.0                  0.921622
# 0   20.0                  0.940012
# Przykładowa wizualizacja

# %% [markdown]
# ### Współczynnik sąsiedztwa = 0.5

# %%
path_name = '..\\evaluation\\(2, 3)_0.5_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/(2, 3)_0.5_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.537464
# 0    5.0                  0.877121
# 0   10.0                  0.867217
# 0   15.0                  0.914030
# 0   20.0                  0.918915
# Przykładowa wizualizacja

# %% [markdown]
# ## Architektura (1, 6) + funkcja gaussa

# %% [markdown]
# ### Współczynnik sąsiedztwa = 1

# %%
path_name = '..\\evaluation\\(1, 6)_1_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/(1, 6)_1_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.511279
# 0    5.0                  0.905296
# 0   10.0                  0.904445
# 0   15.0                  0.908735
# 0   20.0                  0.920003
# Przykładowa wizualizacja

# %% [markdown]
# ### Współczynnik sąsiedztwa = 0.7

# %%
path_name = '..\\evaluation\\(1, 6)_0.7_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/(1, 6)_0.7_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.519036
# 0    5.0                  0.830978
# 0   10.0                  0.892784
# 0   15.0                  0.926787
# 0   20.0                  0.916951
# Przykładowa wizualizacja

# %% [markdown]
# ### Współczynnik sąsiedztwa = 0.5

# %%
path_name = '..\\evaluation\\(1, 6)_0.5_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/(1, 6)_0.5_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.547360
# 0    5.0                  0.912557
# 0   10.0                  0.897259
# 0   15.0                  0.908743
# 0   20.0                  0.903501
# Przykładowa wizualizacja

# %% [markdown]
# ## Architektura (2, 3) + funkcja mexico hat

# %% [markdown]
# ### Współczynnik sąsiedztwa = 1

# %%
path_name = '..\\evaluation\\(2, 3)_1_gaussian_second_derivative_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/(2, 3)_1_gaussian_second_derivative_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                   0.48664
# 0    5.0                   0.00000
# 0   10.0                   0.00000
# 0   15.0                   0.00000
# 0   20.0                   0.00000
# Przykładowa wizualizacja

# %% [markdown]
# ### Współczynnik sąsiedztwa = 0.7

# %%
path_name = '..\\evaluation\\(2, 3)_0.7_gaussian_second_derivative_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/(2, 3)_0.7_gaussian_second_derivative_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.556561
# 0    5.0                  0.000000
# 0   10.0                  0.000000
# 0   15.0                  0.000000
# 0   20.0                  0.000000
# Przykładowa wizualizacja

# %% [markdown]
# ### Współczynnik sąsiedztwa = 0.5

# %%
path_name = '..\\evaluation\\(2, 3)_0.5_gaussian_second_derivative_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/(2, 3)_0.5_gaussian_second_derivative_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.536241
# 0    5.0                  0.650066
# 0   10.0                  0.705423
# 0   15.0                  0.736018
# 0   20.0                  0.858586
# Przykładowa wizualizacja

# %%
path_name = '..\\evaluation\\(2, 3)_0.3_gaussian_second_derivative_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/(2, 3)_0.3_gaussian_second_derivative_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.508211
# 0    5.0                  0.592354
# 0   10.0                  0.708320
# 0   15.0                  0.813434
# 0   20.0                  0.899294
# Przykładowa wizualizacja

# %%
path_name = '..\\evaluation\\(2, 3)_0.1_gaussian_second_derivative_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/(2, 3)_0.1_gaussian_second_derivative_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.499957
# 0    5.0                  0.418494
# 0   10.0                  0.509147
# 0   15.0                  0.705072
# 0   20.0                  0.878250
# Przykładowa wizualizacja

# %% [markdown]
# ## Architektura (1, 6) + funkcja mexico hat

# %% [markdown]
# ### Współczynnik sąsiedztwa = 1

# %%
path_name = '..\\evaluation\\(1, 6)_1_gaussian_second_derivative_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/(1, 6)_1_gaussian_second_derivative_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.506235
# 0    5.0                  0.000000
# 0   10.0                  0.000000
# 0   15.0                  0.000000
# 0   20.0                  0.000000
# Przykładowa wizualizacja

# %% [markdown]
# ### Współczynnik sąsiedztwa = 0.7

# %%
path_name = '..\\evaluation\\(1, 6)_0.7_gaussian_second_derivative_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/(1, 6)_0.7_gaussian_second_derivative_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.553124
# 0    5.0                  0.000000
# 0   10.0                  0.000000
# 0   15.0                  0.000000
# 0   20.0                  0.000000
# Przykładowa wizualizacja

# %% [markdown]
# ### Współczynnik sąsiedztwa = 0.5

# %%
path_name = '..\\evaluation\\(1, 6)_0.5_gaussian_second_derivative_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/(1, 6)_0.5_gaussian_second_derivative_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.569045
# 0    5.0                  0.457824
# 0   10.0                  0.525388
# 0   15.0                  0.576359
# 0   20.0                  0.639763
# Przykładowa wizualizacja

# %% [markdown]
# ### Współczynnik sąsiedztwa = 0.3

# %%
path_name = '..\\evaluation\\(1, 6)_0.3_gaussian_second_derivative_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/(1, 6)_0.3_gaussian_second_derivative_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.576281
# 0    5.0                  0.313939
# 0   10.0                  0.363908
# 0   15.0                  0.489341
# 0   20.0                  0.485739
# Przykładowa wizualizacja

# %% [markdown]
# ### Współczynnik sąsiedztwa = 0.1

# %%
path_name = '..\\evaluation\\(1, 6)_0.1_gaussian_second_derivative_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/(1, 6)_0.1_gaussian_second_derivative_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.554032
# 0    5.0                  0.385707
# 0   10.0                  0.540353
# 0   15.0                  0.718473
# 0   20.0                  0.781909
# Przykładowa wizualizacja

# %% [markdown]
# # Cube

# %% [markdown]
# ## Architektura (2, 4) + funkcja gaussa

# %% [markdown]
# ### Współczynnik sąsiedztwa = 1

# %%
path_name = '..\\evaluation\\cube_(2, 4)_1_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'})
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.250022
# 0    5.0                  0.658093
# 0   10.0                  0.737869
# 0   15.0                  0.821040
# 0   20.0                  0.873200

# %%
print('Przykładowa wizualizacja')
Image(filename='../evaluation/cube_(2, 4)_1_cv_4/epoch_20.png')
# Out:
# Przykładowa wizualizacja

# %% [markdown]
# ### Współczynnik sąsiedztwa = 0.7

# %%
path_name = '..\\evaluation\\cube_(2, 4)_0.7_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'})
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.237149
# 0    5.0                  0.686688
# 0   10.0                  0.746149
# 0   15.0                  0.751661
# 0   20.0                  0.859995

# %%
print('Przykładowa wizualizacja')
Image(filename='../evaluation/cube_(2, 4)_0.7_cv_4/epoch_20.png')
# Out:
# Przykładowa wizualizacja

# %% [markdown]
# ### Współczynnik sąsiedztwa = 0.5

# %%
path_name = '..\\evaluation\\cube_(2, 4)_0.5_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/cube_(2, 4)_0.5_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.235892
# 0    5.0                  0.712906
# 0   10.0                  0.754894
# 0   15.0                  0.809421
# 0   20.0                  0.855596
# Przykładowa wizualizacja

# %% [markdown]
# ## Architektura (1, 8) + funkcja gaussa
# ### Współczynnik sąsiedztwa = 1

# %%
path_name = '..\\evaluation\\cube_(1, 8)_1_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/cube_(1, 8)_1_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.267852
# 0    5.0                  0.656810
# 0   10.0                  0.693846
# 0   15.0                  0.840544
# 0   20.0                  0.857081
# Przykładowa wizualizacja

# %% [markdown]
# ### Współczynnik sąsiedztwa = 0.7

# %%
path_name = '..\\evaluation\\cube_(1, 8)_0.7_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/cube_(1, 8)_0.7_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.220424
# 0    5.0                  0.727706
# 0   10.0                  0.682860
# 0   15.0                  0.852756
# 0   20.0                  0.860044
# Przykładowa wizualizacja

# %% [markdown]
# ### Współczynnik sąsiedztwa = 0.5

# %%
path_name = '..\\evaluation\\cube_(1, 8)_0.5_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/cube_(1, 8)_0.5_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.335482
# 0    5.0                  0.733534
# 0   10.0                  0.744744
# 0   15.0                  0.859789
# 0   20.0                  0.829446
# Przykładowa wizualizacja

# %% [markdown]
# ## Architektura (2, 4) + funkcja mexico hat
# ### Współczynnik sąsiedztwa = 1

# %%
path_name = '..\\evaluation\\cube_(2, 4)_1_gaussian_second_derivative_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/cube_(2, 4)_1_gaussian_second_derivative_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.226492
# 0    5.0                  0.000000
# 0   10.0                  0.000000
# 0   15.0                  0.000000
# 0   20.0                  0.000000
# Przykładowa wizualizacja

# %%
path_name = '..\\evaluation\\cube_(2, 4)_0.7_gaussian_second_derivative_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/cube_(2, 4)_0.7_gaussian_second_derivative_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.246869
# 0    5.0                  0.000000
# 0   10.0                  0.000000
# 0   15.0                  0.000000
# 0   20.0                  0.000000
# Przykładowa wizualizacja

# %%
path_name = '..\\evaluation\\cube_(2, 4)_0.5_gaussian_second_derivative_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/cube_(2, 4)_0.5_gaussian_second_derivative_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.261586
# 0    5.0                  0.472610
# 0   10.0                  0.567084
# 0   15.0                  0.608465
# 0   20.0                  0.591580
# Przykładowa wizualizacja

# %%
path_name = '..\\evaluation\\cube_(2, 4)_0.3_gaussian_second_derivative_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/cube_(2, 4)_0.3_gaussian_second_derivative_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.270442
# 0    5.0                  0.523366
# 0   10.0                  0.539221
# 0   15.0                  0.690296
# 0   20.0                  0.705038
# Przykładowa wizualizacja

# %% [markdown]
# ### Współczynnik sąsiedztwa = 0.1

# %%
path_name = '..\\evaluation\\cube_(2, 4)_0.1_gaussian_second_derivative_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/cube_(2, 4)_0.1_gaussian_second_derivative_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.278917
# 0    5.0                  0.269760
# 0   10.0                  0.422788
# 0   15.0                  0.639615
# 0   20.0                  0.615257
# Przykładowa wizualizacja

# %% [markdown]
# ## Architektura (1, 8) z funkcją mexican hat
# ### Współczynnik sąsiedztwa = 1

# %%
path_name = '..\\evaluation\\cube_(1, 8)_1_gaussian_second_derivative_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/cube_(1, 8)_1_gaussian_second_derivative_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.278742
# 0    5.0                  0.000000
# 0   10.0                  0.000000
# 0   15.0                  0.000000
# 0   20.0                  0.000000
# Przykładowa wizualizacja

# %% [markdown]
# ### Współczynnik sąsiedztwa = 0.7

# %%
path_name = '..\\evaluation\\cube_(1, 8)_0.7_gaussian_second_derivative_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/cube_(1, 8)_0.7_gaussian_second_derivative_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.282039
# 0    5.0                  0.000000
# 0   10.0                  0.000000
# 0   15.0                  0.000000
# 0   20.0                  0.000000
# Przykładowa wizualizacja

# %% [markdown]
# ### Współczynnik sąsiedztwa = 0.5

# %%
path_name = '..\\evaluation\\cube_(1, 8)_0.5_gaussian_second_derivative_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/cube_(1, 8)_0.5_gaussian_second_derivative_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.280455
# 0    5.0                  0.000000
# 0   10.0                  0.000000
# 0   15.0                  0.000000
# 0   20.0                  0.000000
# Przykładowa wizualizacja

# %% [markdown]
# ### Współczynnik sąsiedztwa = 0.3

# %%
path_name = '..\\evaluation\\cube_(1, 8)_0.3_gaussian_second_derivative_cv_{idx}.csv'
histories = [load_history(path_name.format(idx=i)) for i in range(5)]

results_df = mean_scores(histories)
results_df.insert(0, 'epoch', histories[0]['epoch'])
print(results_df.rename(columns={'adjusted rand score': 'mean adjusted rand score'}))

print('Przykładowa wizualizacja')
Image(filename='../evaluation/cube_(1, 8)_0.3_gaussian_second_derivative_cv_4/epoch_20.png')
# Out:
#    epoch  mean adjusted rand score
# 0    0.0                  0.302383
# 0    5.0                  0.000000
# 0   10.0                  0.000000
# 0   15.0                  0.000000
# 0   20.0                  0.000000
# Przykładowa wizualizacja

# %%
### Współczynnik sąsiedztwa = 0.1
